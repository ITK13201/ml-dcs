# %%
from ml_dcs.config import config  # NOQA

# %%
from ml_dcs.internal.ml.prediction_methods import RandomForestPrediction
from ml_dcs.domain.ml import MLMemoryUsagePredictionInput2
from ml_dcs.usecase.evaluator import RandomStateEvaluator

evaluator = RandomStateEvaluator(input_dir_path="./tmp/2024-08-11/input", ml_input_class=MLMemoryUsagePredictionInput2, prediction_class=RandomForestPrediction)
result = evaluator.evaluate()
print(result)
evaluator.plt_show()
# Out:
# [INFO] 2024-08-12 08:44:57,438 utils 1758 139880016320320 Note: NumExpr detected 20 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# [INFO] 2024-08-12 08:44:57,438 utils 1758 139880016320320 NumExpr defaulting to 8 threads.
# (0.4529628975228316, 8878923.71654762)

# %%
from ml_dcs.internal.ml.prediction_methods import GradientBoostingPrediction
from ml_dcs.domain.ml import MLMemoryUsagePredictionInput2
from ml_dcs.usecase.evaluator import RandomStateEvaluator

evaluator = RandomStateEvaluator(input_dir_path="./tmp/2024-08-11/input", ml_input_class=MLMemoryUsagePredictionInput2, prediction_class=GradientBoostingPrediction)
result = evaluator.evaluate()
print(result)
evaluator.plt_show()
# Out:
# (0.5234183641280021, 9984544.792051503)

# %%
from ml_dcs.internal.ml.prediction_methods import DecisionTreePrediction
from ml_dcs.domain.ml import MLMemoryUsagePredictionInput2
from ml_dcs.usecase.evaluator import RandomStateEvaluator

evaluator = RandomStateEvaluator(input_dir_path="./tmp/2024-08-11/input", ml_input_class=MLMemoryUsagePredictionInput2, prediction_class=DecisionTreePrediction)
result = evaluator.evaluate()
print(result)
evaluator.plt_show()
# Out:
# (-0.21936653525041816, 11508761.4)

# %%
from ml_dcs.internal.ml.prediction_methods import LogisticRegressionPrediction
from ml_dcs.domain.ml import MLMemoryUsagePredictionInput2
from ml_dcs.usecase.evaluator import RandomStateEvaluator

evaluator = RandomStateEvaluator(input_dir_path="./tmp/2024-08-11/input", ml_input_class=MLMemoryUsagePredictionInput2, prediction_class=LogisticRegressionPrediction)
result = evaluator.evaluate()
print(result)
evaluator.plt_show()
# Out:
# (0.1448598810988957, 7785544.0)
