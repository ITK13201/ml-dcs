# %%
from ml_dcs.config import config # NOQA
import json

SIMPLE_INPUT_PATH = lambda algorithm: f"tmp/prod-results/results-20241214/20241125_memory-usage/simple/20241213-193240/testing-result_{algorithm}.json"
GNN_INPUT_PATH_L1 = "tmp/prod-results/results-20241214/20241125_memory-usage/gnn-L1/20241213-194417/testing-result.json"
GNN_INPUT_PATH_L2 = "tmp/prod-results/results-20241214/20241125_memory-usage/gnn-L2/20241213-201231/testing-result.json"
GNN_INPUT_PATH_L3 = "tmp/prod-results/results-20241214/20241125_memory-usage/gnn-L3/20241213-211017/testing-result.json"
X_LABEL = "Actual values (KB)"
Y_LABEL = "Predicted values (KB)"
ORDER_OF_MAG = 6
LIM = (-1 * 10**ORDER_OF_MAG, 8 * 10**ORDER_OF_MAG)
SCENARIO = "ArtGallery"
results_mae = []
results_rmse = []

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("RF"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 12:00:20,338 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 158 140737476416000: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.8120816120357602, "mae": 390277.6371548409}
# {"mae": 390277.6371548409, "rmse": 757165.1839921527}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("GBDT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 12:00:20,481 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 158 140737476416000: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.6672114265161233, "mae": 528484.1800280453}
# {"mae": 528484.1800280453, "rmse": 1007604.73552721}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("DT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 12:00:20,616 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 158 140737476416000: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.4950084416734041, "mae": 577736.5348258705}
# {"mae": 577736.5348258705, "rmse": 1241217.9742454288}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("LR"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 12:00:20,766 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 158 140737476416000: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.6388521226124262, "mae": 548065.7910447761}
# {"mae": 548065.7910447761, "rmse": 1049659.7162804573}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L1)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 12:00:20,911 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 158 140737476416000: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.23301279695321242, "mae": 998942.0787954758}
# {"mae": 998942.0787954758, "rmse": 1529678.123934857}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L2)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 12:00:21,069 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 158 140737476416000: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.7803391620866645, "mae": 466088.6161089086}
# {"mae": 466088.6161089086, "rmse": 818619.9321321361}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L3)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 12:00:21,248 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 158 140737476416000: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.6601616199747992, "mae": 747576.7425373135}
# {"mae": 747576.7425373135, "rmse": 1018221.3740082894}

# %%
# FOR TABLE
import pandas as pd

pd.DataFrame({
    "MAE": [v / 1000 for v in results_mae],
    "RMSE": [v / 1000 for v in results_rmse]
})
# Out:
#          MAE        RMSE
# 0 390.277637  757.165184
# 1 528.484180 1007.604736
# 2 577.736535 1241.217974
# 3 548.065791 1049.659716
# 4 998.942079 1529.678124
# 5 466.088616  818.619932
# 6 747.576743 1018.221374
