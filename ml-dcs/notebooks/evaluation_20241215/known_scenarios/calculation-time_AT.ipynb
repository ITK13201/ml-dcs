# %%
from ml_dcs.config import config  # NOQA
import json

SIMPLE_INPUT_PATH = (
    lambda algorithm: f"tmp/prod-results/results-20241214/20241125_calculation-time/simple/20241213-084747/testing-result_{algorithm}.json"
)
GNN_INPUT_PATH_L1 = "tmp/prod-results/results-20241214/20241125_calculation-time/gnn-L1/20241213-085923/testing-result.json"
GNN_INPUT_PATH_L2 = "tmp/prod-results/results-20241214/20241125_calculation-time/gnn-L2/20241213-092809/testing-result.json"
GNN_INPUT_PATH_L3 = "tmp/prod-results/results-20241214/20241125_calculation-time/gnn-L3/20241213-100027/testing-result.json"
X_LABEL = "Actual values (ms)"
Y_LABEL = "Predicted values (ms)"
ORDER_OF_MAG = 5
LIM = (-0.2 * 10**ORDER_OF_MAG, 3 * 10**ORDER_OF_MAG)
SCENARIO = "AT"
results_mae = []
results_rmse = []

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("RF"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:56:22,641 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 10 140737476416000: accuracy evaluate: {"scenario": "AT", "r2": 0.9995475890737705, "mae": 201.21423590974507}
# {"mae": 201.21423590974507, "rmse": 761.5405451631627}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("GBDT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:56:22,789 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 10 140737476416000: accuracy evaluate: {"scenario": "AT", "r2": 0.9976040633056805, "mae": 663.9809628626912}
# {"mae": 663.9809628626912, "rmse": 1752.524739757583}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("DT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:56:23,627 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 10 140737476416000: accuracy evaluate: {"scenario": "AT", "r2": 0.9993544647682291, "mae": 237.08477133427624}
# {"mae": 237.08477133427624, "rmse": 909.6754263968322}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("LR"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:56:23,738 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 10 140737476416000: accuracy evaluate: {"scenario": "AT", "r2": 0.5039327334576367, "mae": 6095.112211221122}
# {"mae": 6095.112211221122, "rmse": 25217.194800648653}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L1)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:56:24,197 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 10 140737476416000: accuracy evaluate: {"scenario": "AT", "r2": 0.8426092746903707, "mae": 5728.84996440623}
# {"mae": 5728.84996440623, "rmse": 14204.176376263917}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L2)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:56:24,315 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 10 140737476416000: accuracy evaluate: {"scenario": "AT", "r2": 0.8489475257231863, "mae": 4911.282150218196}
# {"mae": 4911.282150218196, "rmse": 13915.23066450167}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L3)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:56:24,445 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 10 140737476416000: accuracy evaluate: {"scenario": "AT", "r2": 0.8227206594182918, "mae": 5420.016737632625}
# {"mae": 5420.016737632625, "rmse": 15074.938595955076}

# %%
# FOR TABLE
import pandas as pd

pd.DataFrame(
    {"MAE": [v / 1000 for v in results_mae], "RMSE": [v / 1000 for v in results_rmse]}
)
# Out:
#         MAE       RMSE
# 0  0.201214   0.761541
# 1  0.663981   1.752525
# 2  0.237085   0.909675
# 3  6.095112  25.217195
# 4  5.728850  14.204176
# 5  4.911282  13.915231
# 6  5.420017  15.074939
