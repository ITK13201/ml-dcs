# %%
from ml_dcs.config import config # NOQA
import json

SIMPLE_INPUT_PATH = lambda algorithm: f"tmp/prod-results/results-20241214/20241125_calculation-time/simple/20241213-084747/testing-result_{algorithm}.json"
GNN_INPUT_PATH_L1 = "tmp/prod-results/results-20241214/20241125_calculation-time/gnn-L1/20241213-085923/testing-result.json"
GNN_INPUT_PATH_L2 = "tmp/prod-results/results-20241214/20241125_calculation-time/gnn-L2/20241213-092809/testing-result.json"
GNN_INPUT_PATH_L3 = "tmp/prod-results/results-20241214/20241125_calculation-time/gnn-L3/20241213-100027/testing-result.json"
X_LABEL = "Actual values (ms)"
Y_LABEL = "Predicted values (ms)"
ORDER_OF_MAG = 5
LIM = (-0.2 * 10**ORDER_OF_MAG, 3 * 10**ORDER_OF_MAG)
SCENARIO = "CM"
results_mae = []
results_rmse = []

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("RF"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:57:26,257 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 57 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.8670657770749364, "mae": 5875.679549730697}
# {"mae": 5875.679549730697, "rmse": 16993.564740576465}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("GBDT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:57:26,403 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 57 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.8775639959018207, "mae": 5995.396719924414}
# {"mae": 5995.396719924414, "rmse": 16308.749549736476}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("DT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:57:26,548 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 57 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.8703295993970754, "mae": 5856.603910961263}
# {"mae": 5856.603910961263, "rmse": 16783.653931556782}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("LR"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:57:26,695 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 57 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.9007372216455372, "mae": 5366.357142857143}
# {"mae": 5366.357142857143, "rmse": 14684.50472124148}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L1)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:57:26,849 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 57 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.4448996713445822, "mae": 16343.033298181028}
# {"mae": 16343.033298181028, "rmse": 34725.76580764451}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L2)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:57:27,040 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 57 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.5721796081651775, "mae": 21493.417355907208}
# {"mae": 21493.417355907208, "rmse": 30485.746244830745}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L3)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:57:27,197 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 57 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.4457265281885091, "mae": 22577.120037468114}
# {"mae": 22577.120037468114, "rmse": 34699.893063430594}

# %%
# FOR TABLE
import pandas as pd

pd.DataFrame({
    "MAE": [v/1000 for v in results_mae],
    "RMSE": [v/1000 for v in results_rmse]
})
# Out:
#          MAE       RMSE
# 0   5.875680  16.993565
# 1   5.995397  16.308750
# 2   5.856604  16.783654
# 3   5.366357  14.684505
# 4  16.343033  34.725766
# 5  21.493417  30.485746
# 6  22.577120  34.699893
