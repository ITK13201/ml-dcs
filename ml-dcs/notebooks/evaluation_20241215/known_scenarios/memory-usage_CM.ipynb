# %%
from ml_dcs.config import config  # NOQA
import json

SIMPLE_INPUT_PATH = (
    lambda algorithm: f"tmp/prod-results/results-20241214/20241125_memory-usage/simple/20241213-193240/testing-result_{algorithm}.json"
)
GNN_INPUT_PATH_L1 = "tmp/prod-results/results-20241214/20241125_memory-usage/gnn-L1/20241213-194417/testing-result.json"
GNN_INPUT_PATH_L2 = "tmp/prod-results/results-20241214/20241125_memory-usage/gnn-L2/20241213-201231/testing-result.json"
GNN_INPUT_PATH_L3 = "tmp/prod-results/results-20241214/20241125_memory-usage/gnn-L3/20241213-211017/testing-result.json"
X_LABEL = "Actual values (KB)"
Y_LABEL = "Predicted values (KB)"
ORDER_OF_MAG = 6
LIM = (-1 * 10**ORDER_OF_MAG, 8 * 10**ORDER_OF_MAG)
SCENARIO = "CM"
results_mae = []
results_rmse = []

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("RF"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:59:37,872 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 138 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.9967470794720598, "mae": 27217.186096546106}
# {"mae": 27217.186096546106, "rmse": 94632.04993430851}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("GBDT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:59:37,987 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 138 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.9954161344876461, "mae": 41623.140634980286}
# {"mae": 41623.140634980286, "rmse": 112335.6118214515}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("DT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:59:38,098 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 138 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.9968071199047731, "mae": 26605.628681774702}
# {"mae": 26605.628681774702, "rmse": 93754.65198853212}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("LR"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:59:38,249 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 138 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.9481098445330095, "mae": 183510.63917525773}
# {"mae": 183510.63917525773, "rmse": 377958.4047579512}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L1)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:59:38,373 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 138 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": -0.23970643510285194, "mae": 811279.2930794941}
# {"mae": 811279.2930794941, "rmse": 1847400.0419261286}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L2)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:59:38,587 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 138 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.8828587023793207, "mae": 423008.61656330543}
# {"mae": 423008.61656330543, "rmse": 567879.9516024909}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L3)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:59:38,698 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 138 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.432968729666073, "mae": 756146.7222938144}
# {"mae": 756146.7222938144, "rmse": 1249410.1399276836}

# %%
# FOR TABLE
import pandas as pd

pd.DataFrame(
    {"MAE": [v / 1000 for v in results_mae], "RMSE": [v / 1000 for v in results_rmse]}
)
# Out:
#          MAE        RMSE
# 0  27.217186   94.632050
# 1  41.623141  112.335612
# 2  26.605629   93.754652
# 3 183.510639  377.958405
# 4 811.279293 1847.400042
# 5 423.008617  567.879952
# 6 756.146722 1249.410140
