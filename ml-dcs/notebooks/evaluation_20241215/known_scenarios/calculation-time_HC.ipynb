# %%
from ml_dcs.config import config # NOQA
import json

SIMPLE_INPUT_PATH = lambda algorithm: f"tmp/prod-results/results-20241214/20241125_calculation-time/simple/20241213-084747/testing-result_{algorithm}.json"
GNN_INPUT_PATH_L1 = "tmp/prod-results/results-20241214/20241125_calculation-time/gnn-L1/20241213-085923/testing-result.json"
GNN_INPUT_PATH_L2 = "tmp/prod-results/results-20241214/20241125_calculation-time/gnn-L2/20241213-092809/testing-result.json"
GNN_INPUT_PATH_L3 = "tmp/prod-results/results-20241214/20241125_calculation-time/gnn-L3/20241213-100027/testing-result.json"
X_LABEL = "Actual values (ms)"
Y_LABEL = "Predicted values (ms)"
ORDER_OF_MAG = 5
LIM = (-0.2 * 10**ORDER_OF_MAG, 3 * 10**ORDER_OF_MAG)
SCENARIO = "ArtGallery"
results_mae = []
results_rmse = []

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("RF"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:58:15,983 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 77 140737476416000: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.5575516624291121, "mae": 12881.355832895657}
# {"mae": 12881.355832895657, "rmse": 34696.438370280026}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("GBDT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:58:16,116 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 77 140737476416000: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.4282499585628897, "mae": 15052.497833557558}
# {"mae": 15052.497833557558, "rmse": 39441.79893189081}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("DT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:58:16,249 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 77 140737476416000: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.06169992664244606, "mae": 18823.823529411766}
# {"mae": 18823.823529411766, "rmse": 50527.113369442835}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("LR"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:58:16,360 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 77 140737476416000: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.277548199976411, "mae": 14440.70588235294}
# {"mae": 14440.70588235294, "rmse": 44336.157492569}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L1)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:58:16,475 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 77 140737476416000: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.5029508574024947, "mae": 17103.096702575684}
# {"mae": 17103.096702575684, "rmse": 36775.05042660262}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L2)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:58:16,590 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 77 140737476416000: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.43313296229120923, "mae": 17774.4752926546}
# {"mae": 17774.4752926546, "rmse": 39273.01238746348}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L3)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-16 11:58:16,698 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 77 140737476416000: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.33347850540340673, "mae": 26937.4498165355}
# {"mae": 26937.4498165355, "rmse": 42585.3962043402}

# %%
# FOR TABLE
import pandas as pd

pd.DataFrame({
    "MAE": [v / 1000 for v in results_mae],
    "RMSE": [v / 1000 for v in results_rmse]
})
# Out:
#          MAE       RMSE
# 0  12.881356  34.696438
# 1  15.052498  39.441799
# 2  18.823824  50.527113
# 3  14.440706  44.336157
# 4  17.103097  36.775050
# 5  17.774475  39.273012
# 6  26.937450  42.585396
