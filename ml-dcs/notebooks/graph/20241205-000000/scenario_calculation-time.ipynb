# %%
from ml_dcs.config import config  # NOQA

INPUT_DIR = "./tmp/evaluation/20241125-threshold/output"
GNN_INPUT_PATH = f"{INPUT_DIR}/gnn/calculation-time/20241206-165509/testing-result.json"
SIMPLE_INPUT_PATH = (
    f"{INPUT_DIR}/simple/calculation-time/20241206-152633/testing-result_GBDT.json"
)
X_LABEL = "Actual values (ms)"
Y_LABEL = "Predicted values (ms)"

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6
LIM = (-0.2 * 10**mag, 1 * 10**mag)
SCENARIO = "ArtGallery"

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-06 18:39:22,211 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 664 126763141375808: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.353934591550503, "mae": 47841.45109776088}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 5
LIM = (-0.2 * 10**mag, 1.5 * 10**mag)
SCENARIO = "AT"

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-06 18:28:54,920 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 664 126763141375808: accuracy evaluate: {"scenario": "AT", "r2": 0.7870279335489795, "mae": 10650.599701814874}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 5
LIM = (-0.2 * 10**mag, 0.8 * 10**mag)
SCENARIO = "BW"

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-06 18:28:55,542 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 664 126763141375808: accuracy evaluate: {"scenario": "BW", "r2": -14.139582486149484, "mae": 15707.503580729166}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6
LIM = (-0.2 * 10**mag, 2 * 10**mag)
SCENARIO = "CM"

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-06 18:28:56,293 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 664 126763141375808: accuracy evaluate: {"scenario": "CM", "r2": 0.5008050200668199, "mae": 85994.64739118304}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6
LIM = (-0.15 * 10**mag, 1 * 10**mag)
SCENARIO = "ArtGallery"

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-06 18:32:54,591 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 664 126763141375808: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.45135645613975706, "mae": 41560.242160841786}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 5
LIM = (-0.15 * 10**mag, 1.5 * 10**mag)
SCENARIO = "AT"

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-06 18:33:26,830 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 664 126763141375808: accuracy evaluate: {"scenario": "AT", "r2": 0.9897994046318566, "mae": 1573.1774232045004}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 4
LIM = (-0.15 * 10**mag, 2 * 10**mag)
SCENARIO = "BW"

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-06 18:34:24,389 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 664 126763141375808: accuracy evaluate: {"scenario": "BW", "r2": 0.19109987614374768, "mae": 4845.324195577753}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6
LIM = (-0.15 * 10**mag, 1.75 * 10**mag)
SCENARIO = "CM"

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-06 18:35:58,113 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 664 126763141375808: accuracy evaluate: {"scenario": "CM", "r2": 0.7518690488934145, "mae": 33828.51540649755}
