# %%
from ml_dcs.config import config  # NOQA

INPUT_DIR = "./tmp/evaluation/20241125-threshold/output"
GNN_INPUT_PATH = f"{INPUT_DIR}/gnn/memory-usage/20241207-101044/testing-result.json"
SIMPLE_INPUT_PATH = (
    f"{INPUT_DIR}/simple/memory-usage/20241206-155005/testing-result_GBDT.json"
)
X_LABEL = "Actual values (ms)"
Y_LABEL = "Predicted values (ms)"

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 7
LIM = (-0.2 * 10**mag, 1.75 * 10**mag)
SCENARIO = "ArtGallery"

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-07 10:43:46,504 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 484 134077905512256: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.6094334705691794, "mae": 1020953.8289874188}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6
LIM = (-0.2 * 10**mag, 8 * 10**mag)
SCENARIO = "AT"

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-07 10:43:46,604 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 484 134077905512256: accuracy evaluate: {"scenario": "AT", "r2": 0.9184567653853856, "mae": 177387.24509447673}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6
LIM = (-0.2 * 10**mag, 1.5 * 10**mag)
SCENARIO = "BW"

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-07 10:43:46,678 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 484 134077905512256: accuracy evaluate: {"scenario": "BW", "r2": 0.9751001832981537, "mae": 55330.406901041664}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 7
LIM = (-0.2 * 10**mag, 1.5 * 10**mag)
SCENARIO = "CM"

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-07 10:43:46,774 ml_dcs.usecases.scenario_evaluator:92 evaluate scenario_evaluator 484 134077905512256: accuracy evaluate: {"scenario": "CM", "r2": 0.9932456236022279, "mae": 111186.45762648809}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 7
LIM = (-0.2 * 10**mag, 1.75 * 10**mag)
SCENARIO = "ArtGallery"

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-07 10:43:46,874 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 484 134077905512256: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.649109858639527, "mae": 944525.1718253691}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6
LIM = (-0.2 * 10**mag, 6.5 * 10**mag)
SCENARIO = "AT"

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-07 10:43:46,951 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 484 134077905512256: accuracy evaluate: {"scenario": "AT", "r2": 0.9982891509672305, "mae": 32665.602194023537}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6
LIM = (-0.2 * 10**mag, 1.5 * 10**mag)
SCENARIO = "BW"

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-07 10:43:47,022 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 484 134077905512256: accuracy evaluate: {"scenario": "BW", "r2": 0.2902549034374583, "mae": 241391.59836839323}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 7
LIM = (-0.2 * 10**mag, 1.5 * 10**mag)
SCENARIO = "CM"

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH)
data_model = evaluator.evaluate(SCENARIO)
data = PredictionAccuracyGraphData.from_evaluation_result_class(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-07 10:43:47,122 ml_dcs.usecases.scenario_evaluator:48 evaluate scenario_evaluator 484 134077905512256: accuracy evaluate: {"scenario": "CM", "r2": 0.9916844155007659, "mae": 93087.007386243}
