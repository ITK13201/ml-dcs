# %%
from ml_dcs.config import config # NOQA

INPUT_DIR = "./tmp/prod-results/20241117-021800"
X_LABEL = "Actual values (ms)"
Y_LABEL = "Predicted values (ms)"
X_LIM = (-0.2 * 10**6, 6 * 10**6)
Y_LIM = (-0.2 * 10**6, 6 * 10**6)
# Out:
# PyTorch Device: cuda

# %%
from ml_dcs.internal.graph.graph import GraphUtil
import json
from ml_dcs.domain.ml_gnn import GNNTestingResult
from ml_dcs.domain.graph import Graph, PredictionAccuracyGraphData

input_path = f"{INPUT_DIR}/gnn/calculation-time/testing-result.json"

with open(input_path, "r") as f:
    data_dict = json.load(f)
data_model = GNNTestingResult(**data_dict)
data = PredictionAccuracyGraphData.from_ml_gnn_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=X_LIM,
    y_lim=Y_LIM,
    order_of_mag=6
)
util = GraphUtil(graph)
util.show()

# %%
from ml_dcs.internal.graph.graph import GraphUtil
import json
from ml_dcs.domain.ml_simple import MLSimpleTestingResultSet
from ml_dcs.domain.graph import Graph, PredictionAccuracyGraphData

input_path = f"{INPUT_DIR}/simple/calculation-time/testing-result_GBDT.json"

with open(input_path, "r") as f:
    data_dict = json.load(f)
data_model = MLSimpleTestingResultSet(**data_dict)
data = PredictionAccuracyGraphData.from_ml_simple_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=X_LIM,
    y_lim=Y_LIM,
    order_of_mag=6
)
util = GraphUtil(graph)
util.show()

# %%
from ml_dcs.internal.graph.graph import GraphUtil
import json
from ml_dcs.domain.ml_simple import MLSimpleTestingResultSet
from ml_dcs.domain.graph import Graph, PredictionAccuracyGraphData

input_path = f"{INPUT_DIR}/simple/calculation-time/testing-result_RF.json"

with open(input_path, "r") as f:
    data_dict = json.load(f)
data_model = MLSimpleTestingResultSet(**data_dict)
data = PredictionAccuracyGraphData.from_ml_simple_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=X_LIM,
    y_lim=Y_LIM,
    order_of_mag=6
)
util = GraphUtil(graph)
util.show()

# %%
from ml_dcs.internal.graph.graph import GraphUtil
import json
from ml_dcs.domain.ml_simple import MLSimpleTestingResultSet
from ml_dcs.domain.graph import Graph, PredictionAccuracyGraphData

input_path = f"{INPUT_DIR}/simple/calculation-time/testing-result_DT.json"

with open(input_path, "r") as f:
    data_dict = json.load(f)
data_model = MLSimpleTestingResultSet(**data_dict)
data = PredictionAccuracyGraphData.from_ml_simple_class(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=X_LIM,
    y_lim=Y_LIM,
    order_of_mag=6
)
util = GraphUtil(graph)
util.show()
