# %%
from ml_dcs.config import config  # NOQA

INPUT_DIR = "./tmp/prod-results/20241117-021800"
X_LABEL_MU = "Actual values (KiB)"
Y_LABEL_MU = "Predicted values (KiB)"
X_LIM = (-0.15 * 10**7, 1.1 * 10**7)
Y_LIM = (-0.15 * 10**7, 1.1 * 10**7)
# Out:
# PyTorch Device: cuda

# %%
import json
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.domain.ml_gnn import GNNTestingResult
from ml_dcs.domain.graph import Graph, PredictionAccuracyGraphData

input_path = f"{INPUT_DIR}/gnn/memory-usage/testing-result.json"

with open(input_path, "r") as f:
    data_dict = json.load(f)
data_model = GNNTestingResult(**data_dict)
data = PredictionAccuracyGraphData.from_ml_gnn_class(data_model)
mag = 7
graph = Graph(
    data=data,
    x_label=X_LABEL_MU,
    y_label=Y_LABEL_MU,
    x_lim=X_LIM,
    y_lim=Y_LIM,
)
util = GraphUtil(graph)
util.show()

# %%
import json
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.domain.ml_simple import MLSimpleTestingResultSet
from ml_dcs.domain.graph import Graph, PredictionAccuracyGraphData

input_path = f"{INPUT_DIR}/simple/memory-usage/testing-result_GBDT.json"

with open(input_path, "r") as f:
    data_dict = json.load(f)
data_model = MLSimpleTestingResultSet(**data_dict)
data = PredictionAccuracyGraphData.from_ml_simple_class(data_model)
mag = 7
graph = Graph(
    data=data,
    x_label=X_LABEL_MU,
    y_label=Y_LABEL_MU,
    x_lim=X_LIM,
    y_lim=Y_LIM,
)
util = GraphUtil(graph)
util.show()

# %%
import json
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.domain.ml_simple import MLSimpleTestingResultSet
from ml_dcs.domain.graph import Graph, PredictionAccuracyGraphData

input_path = f"{INPUT_DIR}/simple/memory-usage/testing-result_RF.json"

with open(input_path, "r") as f:
    data_dict = json.load(f)
data_model = MLSimpleTestingResultSet(**data_dict)
data = PredictionAccuracyGraphData.from_ml_simple_class(data_model)
mag = 7
graph = Graph(
    data=data,
    x_label=X_LABEL_MU,
    y_label=Y_LABEL_MU,
    x_lim=X_LIM,
    y_lim=Y_LIM,
)
util = GraphUtil(graph)
util.show()

# %%
import json
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.domain.ml_simple import MLSimpleTestingResultSet
from ml_dcs.domain.graph import Graph, PredictionAccuracyGraphData

input_path = f"{INPUT_DIR}/simple/memory-usage/testing-result_DT.json"

with open(input_path, "r") as f:
    data_dict = json.load(f)
data_model = MLSimpleTestingResultSet(**data_dict)
data = PredictionAccuracyGraphData.from_ml_simple_class(data_model)
mag = 7
graph = Graph(
    data=data,
    x_label=X_LABEL_MU,
    y_label=Y_LABEL_MU,
    x_lim=X_LIM,
    y_lim=Y_LIM,
)
util = GraphUtil(graph)
util.show()
