# %%
from ml_dcs.config import config # NOQA
import json

SIMPLE_INPUT_PATH = lambda algorithm: f"tmp/prod-results/results-20241220/20241220_calculation-time/simple/20241218-223051/testing-result_{algorithm}.json"
GNN_INPUT_PATH_L1 = "tmp/prod-results/results-20241220/20241220_calculation-time/gnn-L1/20241218-224116/testing-result.json"
GNN_INPUT_PATH_L2 = "tmp/prod-results/results-20241220/20241220_calculation-time/gnn-L2/20241218-230732/testing-result.json"
GNN_INPUT_PATH_L3 = "tmp/prod-results/results-20241220/20241220_calculation-time/gnn-L3/20241218-232205/testing-result.json"
X_LABEL = "Actual values (s)"
Y_LABEL = "Predicted values (s)"
ORDER_OF_MAG = 2
LIM = (-0.2 * 10**ORDER_OF_MAG, 3 * 10**ORDER_OF_MAG)
SCENARIO = "CM"
results_mae = []
results_rmse = []
# Out:
# PyTorch Device: cpu

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("RF"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
data_model.dataframe_div1000
# Out:
# [INFO] 2025-01-02 11:19:59,899 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 10 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.8768054988396604, "mae": 5663.951562065259}
# {"mae": 5663.951562065259, "rmse": 16470.478362883958}
#                 lts  actual_values  predicted_values
# 84  CM（2, 2）_000016          0.769          0.833514
# 32  CM（2, 2）_000017          0.769          0.833514
# 28  CM（2, 2）_000003          0.805          0.834839
# 46  CM（2, 2）_000029          0.819          0.797927
# 61  CM（2, 2）_000024          0.831          0.833514
# ..              ...            ...               ...
# 39  CM（3, 3）_000096        162.784        272.182595
# 63  CM（3, 3）_000118        167.939        204.154913
# 35  CM（3, 3）_000121        170.314        148.688916
# 27  CM（3, 3）_000010        246.342        256.225115
# 2   CM（3, 3）_000055        248.654        253.287246
#
# [97 rows x 3 columns]

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("GBDT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-01-02 11:20:00,267 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 10 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.8804125125836255, "mae": 5876.701252685619}
# {"mae": 5876.701252685619, "rmse": 16227.567407514078}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("DT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-01-02 11:20:00,402 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 10 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.8716891941111071, "mae": 5737.33310780372}
# {"mae": 5737.33310780372, "rmse": 16809.011237220373}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("LR"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
data_model.dataframe
# Out:
# [INFO] 2025-01-02 11:20:00,539 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 10 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.8971736249775265, "mae": 5331.896907216495}
# {"mae": 5331.896907216495, "rmse": 15047.446712891846}
#                 lts  actual_values  predicted_values
# 84  CM（2, 2）_000016          769.0             459.0
# 32  CM（2, 2）_000017          769.0             459.0
# 28  CM（2, 2）_000003          805.0             327.0
# 46  CM（2, 2）_000029          819.0             742.0
# 61  CM（2, 2）_000024          831.0             459.0
# ..              ...            ...               ...
# 39  CM（3, 3）_000096       162784.0          252825.0
# 63  CM（3, 3）_000118       167939.0          165672.0
# 35  CM（3, 3）_000121       170314.0          165672.0
# 27  CM（3, 3）_000010       246342.0          268674.0
# 2   CM（3, 3）_000055       248654.0          268674.0
#
# [97 rows x 3 columns]

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L1)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()

data_model.dataframe_div1000
# Out:
# [INFO] 2025-01-02 11:20:00,683 ml_dcs.usecases.scenario_evaluator:99 evaluate scenario_evaluator 10 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.5713345136438162, "mae": 14533.927465694467}
# {"mae": 14533.927465694467, "rmse": 30723.43785232585}
#                 lts  actual_values  predicted_values
# 84  CM（2, 2）_000016          0.769         -0.233997
# 32  CM（2, 2）_000017          0.769         -0.233997
# 28  CM（2, 2）_000003          0.805         -0.233997
# 46  CM（2, 2）_000029          0.819         -0.233997
# 61  CM（2, 2）_000024          0.831         -0.233997
# ..              ...            ...               ...
# 39  CM（3, 3）_000096        162.784        120.639523
# 63  CM（3, 3）_000118        167.939        109.651047
# 35  CM（3, 3）_000121        170.314        100.493953
# 27  CM（3, 3）_000010        246.342        150.857922
# 2   CM（3, 3）_000055        248.654        134.069922
#
# [97 rows x 3 columns]

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L2)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-01-02 11:20:00,886 ml_dcs.usecases.scenario_evaluator:99 evaluate scenario_evaluator 10 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.16908877172672154, "mae": 23561.49203648518}
# {"mae": 23561.49203648518, "rmse": 42774.78792800831}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L3)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-01-02 11:20:01,259 ml_dcs.usecases.scenario_evaluator:99 evaluate scenario_evaluator 10 140737476416000: accuracy evaluate: {"scenario": "CM", "r2": 0.36159218479356925, "mae": 20872.469693842624}
# {"mae": 20872.469693842624, "rmse": 37493.8164193763}

# %%
# FOR TABLE
import pandas as pd

pd.DataFrame({
    "MAE": [v/1000 for v in results_mae],
    "RMSE": [v/1000 for v in results_rmse]
})
# Out:
#          MAE       RMSE
# 0   5.663952  16.470478
# 1   5.876701  16.227567
# 2   5.737333  16.809011
# 3   5.331897  15.047447
# 4  14.533927  30.723438
# 5  23.561492  42.774788
# 6  20.872470  37.493816
