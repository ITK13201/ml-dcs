# %%
from ml_dcs.config import config # NOQA
import json

SIMPLE_INPUT_PATH = lambda algorithm: f"tmp/prod-results/results-20241220/20241220_memory-usage/simple/20241219-061555/testing-result_{algorithm}.json"
GNN_INPUT_PATH_L1 = "tmp/prod-results/results-20241220/20241220_memory-usage/gnn-L1/20241219-062623/testing-result.json"
GNN_INPUT_PATH_L2 = "tmp/prod-results/results-20241220/20241220_memory-usage/gnn-L2/20241219-064457/testing-result.json"
GNN_INPUT_PATH_L3 = "tmp/prod-results/results-20241220/20241220_memory-usage/gnn-L3/20241219-072210/testing-result.json"
X_LABEL = "Actual values (MB)"
Y_LABEL = "Predicted values (MB)"
ORDER_OF_MAG = 3
LIM = (-1 * 10**ORDER_OF_MAG, 8 * 10**ORDER_OF_MAG)
SCENARIO = "ArtGallery"
results_mae = []
results_rmse = []

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("RF"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()

data_model.dataframe_div1000
# Out:
# [INFO] 2024-12-23 10:08:02,284 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 280 135183668303680: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.8050978869322172, "mae": 404963.02020682296}
# {"mae": 404963.02020682296, "rmse": 776634.3009760161}
#                              lts  actual_values  predicted_values
# 50  ArtGallery（N, 2 room）_000190         13.814         19.582597
# 51  ArtGallery（N, 2 room）_000173         16.057         25.617175
# 13  ArtGallery（N, 2 room）_000044         16.483         16.797694
# 11  ArtGallery（N, 2 room）_000128         16.512         19.019005
# 14  ArtGallery（N, 2 room）_000152         16.784         20.770582
# ..                           ...            ...               ...
# 31  ArtGallery（N, 4 room）_000149       4724.251       3968.732710
# 47  ArtGallery（N, 4 room）_000167       5024.165       3034.435770
# 8   ArtGallery（N, 4 room）_000017       5121.164       4701.474890
# 10  ArtGallery（N, 4 room）_000082       6360.232       4064.658390
# 57  ArtGallery（N, 4 room）_000025       6402.364       4038.377380
#
# [67 rows x 3 columns]

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("GBDT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-23 10:08:02,362 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 280 135183668303680: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.642651974285164, "mae": 517218.0713140019}
# {"mae": 517218.0713140019, "rmse": 1051608.2570936095}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("DT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-23 10:08:02,436 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 280 135183668303680: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.5624033171601563, "mae": 563483.1567164179}
# {"mae": 563483.1567164179, "rmse": 1163711.4422319685}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("LR"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-23 10:08:02,514 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 280 135183668303680: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.536408013651804, "mae": 618135.4776119404}
# {"mae": 618135.4776119404, "rmse": 1197777.7849768358}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L1)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-23 10:08:02,706 ml_dcs.usecases.scenario_evaluator:99 evaluate scenario_evaluator 280 135183668303680: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.23176756323663894, "mae": 942958.7541977612}
# {"mae": 942958.7541977612, "rmse": 1541894.339463894}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L2)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-23 10:08:02,781 ml_dcs.usecases.scenario_evaluator:99 evaluate scenario_evaluator 280 135183668303680: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.8061286815084113, "mae": 424289.30824393657}
# {"mae": 424289.30824393657, "rmse": 774577.8540119499}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L3)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2024-12-23 10:08:02,856 ml_dcs.usecases.scenario_evaluator:99 evaluate scenario_evaluator 280 135183668303680: accuracy evaluate: {"scenario": "ArtGallery", "r2": 0.8142570125385561, "mae": 402235.85815065296}
# {"mae": 402235.85815065296, "rmse": 758166.3536573343}

# %%
# FOR TABLE
import pandas as pd

pd.DataFrame({
    "MAE": [v / 1000 for v in results_mae],
    "RMSE": [v / 1000 for v in results_rmse]
})
# Out:
#           MAE         RMSE
# 0  404.963020   776.634301
# 1  517.218071  1051.608257
# 2  563.483157  1163.711442
# 3  618.135478  1197.777785
# 4  942.958754  1541.894339
# 5  424.289308   774.577854
# 6  402.235858   758.166354
