# %%
from ml_dcs.config import config # NOQA
import json

SIMPLE_INPUT_PATH = lambda algorithm: f"tmp/prod-results/results-20241220/20241220_calculation-time/simple/20241218-223051/testing-result_{algorithm}.json"
GNN_INPUT_PATH_L1 = "tmp/prod-results/results-20241220/20241220_calculation-time/gnn-L1/20241218-224116/testing-result.json"
GNN_INPUT_PATH_L2 = "tmp/prod-results/results-20241220/20241220_calculation-time/gnn-L2/20241218-230732/testing-result.json"
GNN_INPUT_PATH_L3 = "tmp/prod-results/results-20241220/20241220_calculation-time_AT/gnn-L3/20241219-021102/testing-result.json"
X_LABEL = "Actual values (s)"
Y_LABEL = "Predicted values (s)"
ORDER_OF_MAG = 2
LIM = (-0.2 * 10**ORDER_OF_MAG, 1.7 * 10**ORDER_OF_MAG)
SCENARIO = "AT"

results_mae = []
results_rmse = []
results_mape = []
# Out:
# PyTorch Device: cuda

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("RF"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:34:28,441 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 264 125952013236032: accuracy evaluate: {"scenario": "AT", "r2": 0.9995277065916535, "mae": 211.6229712587057}
# {"mae": 211.6229712587057, "rmse": 778.051021057869}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("GBDT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:34:28,608 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 264 125952013236032: accuracy evaluate: {"scenario": "AT", "r2": 0.9977955720738964, "mae": 645.7253506136663}
# {"mae": 645.7253506136663, "rmse": 1680.931775258265}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("DT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:34:28,772 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 264 125952013236032: accuracy evaluate: {"scenario": "AT", "r2": 0.9993514107883156, "mae": 237.43230120631108}
# {"mae": 237.43230120631108, "rmse": 911.7735619318922}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("LR"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:34:28,849 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 264 125952013236032: accuracy evaluate: {"scenario": "AT", "r2": 0.6458958108124941, "mae": 4632.40594059406}
# {"mae": 4632.40594059406, "rmse": 21304.31952877534}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L1)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:34:28,928 ml_dcs.usecases.scenario_evaluator:99 evaluate scenario_evaluator 264 125952013236032: accuracy evaluate: {"scenario": "AT", "r2": 0.8341050331916281, "mae": 5518.414855554159}
# {"mae": 5518.414855554159, "rmse": 14582.055262661377}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L2)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:34:29,010 ml_dcs.usecases.scenario_evaluator:99 evaluate scenario_evaluator 264 125952013236032: accuracy evaluate: {"scenario": "AT", "r2": 0.8115518535262441, "mae": 8880.868629077873}
# {"mae": 8880.868629077873, "rmse": 15541.68383813268}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L3)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:34:29,098 ml_dcs.usecases.scenario_evaluator:99 evaluate scenario_evaluator 264 125952013236032: accuracy evaluate: {"scenario": "AT", "r2": 0.49115843905194456, "mae": 21515.390238199827}
# {"mae": 21515.390238199827, "rmse": 25742.366917497704}

# %%
# FOR TABLE
import pandas as pd

pd.DataFrame({
    "MAE": [v/1000 for v in results_mae],
    "RMSE": [v/1000 for v in results_rmse],
    "MAPE": results_mape
})
# Out:
#          MAE       RMSE       MAPE
# 0   0.211623   0.778051   0.010447
# 1   0.645725   1.680932   0.392668
# 2   0.237432   0.911774   0.011478
# 3   4.632406  21.304320   0.178591
# 4   5.518415  14.582055   1.769548
# 5   8.880869  15.541684   6.536568
# 6  21.515390  25.742367  29.651838
