# %%
from ml_dcs.config import config # NOQA
import json

SIMPLE_INPUT_PATH = lambda algorithm: f"tmp/prod-results/results-20241220/20241220_memory-usage/simple/20241219-061555/testing-result_{algorithm}.json"
GNN_INPUT_PATH_L1 = "tmp/prod-results/results-20241220/20241220_memory-usage/gnn-L1/20241219-062623/testing-result.json"
GNN_INPUT_PATH_L2 = "tmp/prod-results/results-20241220/20241220_memory-usage/gnn-L2/20241219-064457/testing-result.json"
GNN_INPUT_PATH_L3 = "tmp/prod-results/results-20241220/20241220_memory-usage/gnn-L3/20241219-072210/testing-result.json"
X_LABEL = "Actual values (MB)"
Y_LABEL = "Predicted values (MB)"
ORDER_OF_MAG = 3
LIM = (-2 * 10**ORDER_OF_MAG, 8 * 10**ORDER_OF_MAG)
SCENARIO = "CM"
results_mae = []
results_rmse = []
results_mape = []
# Out:
# PyTorch Device: cuda

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("RF"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:52:12,667 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 462 129226519549760: accuracy evaluate: {"scenario": "CM", "r2": 0.9964004111717737, "mae": 31471.36580786243}
# {"mae": 31471.36580786243, "rmse": 98588.18030181028}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("GBDT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:52:12,792 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 462 129226519549760: accuracy evaluate: {"scenario": "CM", "r2": 0.9957313341976659, "mae": 40738.70572617034}
# {"mae": 40738.70572617034, "rmse": 107360.4888818767}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("DT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:52:12,948 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 462 129226519549760: accuracy evaluate: {"scenario": "CM", "r2": 0.9967463074752969, "mae": 27668.193440144612}
# {"mae": 27668.193440144612, "rmse": 93731.73538704272}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("LR"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:52:13,014 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 462 129226519549760: accuracy evaluate: {"scenario": "CM", "r2": 0.9831605735244577, "mae": 119592.9191919192}
# {"mae": 119592.9191919192, "rmse": 213236.748207695}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L1)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:52:13,084 ml_dcs.usecases.scenario_evaluator:99 evaluate scenario_evaluator 462 129226519549760: accuracy evaluate: {"scenario": "CM", "r2": -0.03313703646095334, "mae": 814791.7531565657}
# {"mae": 814791.7531565657, "rmse": 1670234.1855225551}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L2)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:52:13,152 ml_dcs.usecases.scenario_evaluator:99 evaluate scenario_evaluator 462 129226519549760: accuracy evaluate: {"scenario": "CM", "r2": 0.7956273991671362, "mae": 411159.02937578916}
# {"mae": 411159.02937578916, "rmse": 742864.7294463491}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L3)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({
    "mae": data_model.mae,
    "rmse": data_model.rmse
}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    x_lim=LIM,
    y_lim=LIM,
    order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
data_model.dataframe_div1000
# Out:
# [INFO] 2025-03-20 09:52:13,221 ml_dcs.usecases.scenario_evaluator:99 evaluate scenario_evaluator 462 129226519549760: accuracy evaluate: {"scenario": "CM", "r2": 0.9657520322805827, "mae": 157633.88257575757}
# {"mae": 157633.88257575757, "rmse": 304099.56981129484}
#                 lts  actual_values  predicted_values
# 94  CM（2, 2）_000021         27.980       -613.997625
# 59  CM（2, 2）_000001         30.127       -873.836812
# 0   CM（2, 2）_000004         31.374       -873.836812
# 34  CM（2, 3）_000120         85.839        168.136422
# 53  CM（2, 3）_000114         89.443        182.862687
# ..              ...            ...               ...
# 97  CM（3, 3）_000102       6353.506       6905.284000
# 4   CM（3, 3）_000099       7009.365       6905.284000
# 58  CM（3, 3）_000092       7011.673       7592.251500
# 57  CM（3, 3）_000104       7011.730       6905.283000
# 84  CM（3, 3）_000105       7154.333       6905.284000
#
# [99 rows x 3 columns]

# %%
# FOR TABLE
import pandas as pd

pd.DataFrame({
    "MAE": [v / 1000 for v in results_mae],
    "RMSE": [v / 1000 for v in results_rmse],
    "MAPE": results_mape
})
# Out:
#           MAE         RMSE      MAPE
# 0   31.471366    98.588180  0.038423
# 1   40.738706   107.360489  0.091974
# 2   27.668193    93.731735  0.028895
# 3  119.592919   213.236748  0.249517
# 4  814.791753  1670.234186  2.418761
# 5  411.159029   742.864729  0.628907
# 6  157.633883   304.099570  1.205639
