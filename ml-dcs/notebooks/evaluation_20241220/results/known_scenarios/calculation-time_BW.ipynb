# %%
from ml_dcs.config import config  # NOQA
import json

SIMPLE_INPUT_PATH = (
    lambda algorithm: f"tmp/prod-results/results-20241220/20241220_calculation-time/simple/20241218-223051/testing-result_{algorithm}.json"
)
GNN_INPUT_PATH_L1 = "tmp/prod-results/results-20241220/20241220_calculation-time/gnn-L1/20241218-224116/testing-result.json"
GNN_INPUT_PATH_L2 = "tmp/prod-results/results-20241220/20241220_calculation-time/gnn-L2/20241218-230732/testing-result.json"
GNN_INPUT_PATH_L3 = "tmp/prod-results/results-20241220/20241220_calculation-time/gnn-L3/20241218-232205/testing-result.json"
X_LABEL = "Actual values (s)"
Y_LABEL = "Predicted values (s)"
ORDER_OF_MAG = 1
LIM = (-0.2 * 10**ORDER_OF_MAG, 4.5 * 10**ORDER_OF_MAG)
SCENARIO = "BW"
results_mae = []
results_rmse = []
results_mape = []
# Out:
# PyTorch Device: cuda

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("RF"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:36:13,913 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 297 131726151124800: accuracy evaluate: {"scenario": "BW", "r2": 0.8172853445228088, "mae": 2997.9070190358098}
# {"mae": 2997.9070190358098, "rmse": 6756.217982774379}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("GBDT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:36:14,037 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 297 131726151124800: accuracy evaluate: {"scenario": "BW", "r2": 0.48686279541986954, "mae": 5663.555527648247}
# {"mae": 5663.555527648247, "rmse": 11322.27537838704}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("DT"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:36:14,181 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 297 131726151124800: accuracy evaluate: {"scenario": "BW", "r2": 0.9998714254140818, "mae": 93.8}
# {"mae": 93.8, "rmse": 179.22332437492616}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import SimpleScenarioEvaluator

mag = 6

evaluator = SimpleScenarioEvaluator(SIMPLE_INPUT_PATH("LR"))
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:36:14,247 ml_dcs.usecases.scenario_evaluator:52 evaluate scenario_evaluator 297 131726151124800: accuracy evaluate: {"scenario": "BW", "r2": -0.27315800413652913, "mae": 8348.8}
# {"mae": 8348.8, "rmse": 17834.384020761692}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L1)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:36:14,317 ml_dcs.usecases.scenario_evaluator:99 evaluate scenario_evaluator 297 131726151124800: accuracy evaluate: {"scenario": "BW", "r2": 0.9112370251117036, "mae": 2732.4233215332033}
# {"mae": 2732.4233215332033, "rmse": 4709.045493413997}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L2)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:36:14,387 ml_dcs.usecases.scenario_evaluator:99 evaluate scenario_evaluator 297 131726151124800: accuracy evaluate: {"scenario": "BW", "r2": -0.031803396837003284, "mae": 14112.2599609375}
# {"mae": 14112.2599609375, "rmse": 16055.189583409505}

# %%
from ml_dcs.domain.graph import PredictionAccuracyGraphData, Graph
from ml_dcs.internal.graph.graph import GraphUtil
from ml_dcs.usecases.scenario_evaluator import GNNScenarioEvaluator

mag = 6

evaluator = GNNScenarioEvaluator(GNN_INPUT_PATH_L3)
data_model = evaluator.evaluate(SCENARIO)
print(json.dumps({"mae": data_model.mae, "rmse": data_model.rmse}))
results_mae.append(data_model.mae)
results_rmse.append(data_model.rmse)
results_mape.append(data_model.mape)
data = PredictionAccuracyGraphData.from_evaluation_result_class_div1000(data_model)
graph = Graph(
    data=data, x_label=X_LABEL, y_label=Y_LABEL, x_lim=LIM, y_lim=LIM, order_of_mag=mag
)
util = GraphUtil(graph)
util.show()
# Out:
# [INFO] 2025-03-20 09:36:14,452 ml_dcs.usecases.scenario_evaluator:99 evaluate scenario_evaluator 297 131726151124800: accuracy evaluate: {"scenario": "BW", "r2": 0.8441515004587092, "mae": 4125.186669921875}
# {"mae": 4125.186669921875, "rmse": 6239.765581821958}

# %%
# FOR TABLE
import pandas as pd

pd.DataFrame(
    {
        "MAE": [v / 1000 for v in results_mae],
        "RMSE": [v / 1000 for v in results_rmse],
        "MAPE": results_mape,
    }
)
# Out:
#          MAE       RMSE       MAPE
# 0   2.997907   6.756218   0.141215
# 1   5.663556  11.322275   1.555866
# 2   0.093800   0.179223   0.041851
# 3   8.348800  17.834384   0.420390
# 4   2.732423   4.709045   1.227497
# 5  14.112260  16.055190  24.917511
# 6   4.125187   6.239766   3.474482
