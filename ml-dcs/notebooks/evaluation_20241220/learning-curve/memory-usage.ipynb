# %%
from ml_dcs.config import config # NOQA

GNN_INPUT_PATH_L1 = "tmp/prod-results/results-20241220/20241220_memory-usage/gnn-L1/20241219-062623/training-result.json"
GNN_INPUT_PATH_L2 = "tmp/prod-results/results-20241220/20241220_memory-usage/gnn-L2/20241219-064457/training-result.json"
GNN_INPUT_PATH_L3 = "tmp/prod-results/results-20241220/20241220_memory-usage/gnn-L3/20241219-072210/training-result.json"

X_LABEL = "Epoch"
Y_LABEL = "MSE Loss (MB$^2$)"
Y1_LEGEND = "train"
Y2_LEGEND = "validation"
MAGNITUDE = 6
Y_LIM = [-0.1 * 10**MAGNITUDE, 3.2 * 10**MAGNITUDE]

# %%
import json
from ml_dcs.internal.graph.graph import Graph2Util
from ml_dcs.domain.ml_gnn import GNNTrainingResult
from ml_dcs.domain.graph import Graph2, LearningCurveGraphData

with open(GNN_INPUT_PATH_L1, "r") as f:
    data_dict = json.load(f)
data_model = GNNTrainingResult(**data_dict)
data = LearningCurveGraphData.from_ml_gnn_training_result_class_div1000(data_model)
graph = Graph2(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    y1_legend=Y1_LEGEND,
    y2_legend=Y2_LEGEND,
    y_lim=Y_LIM,
    order_of_mag=MAGNITUDE
)
util = Graph2Util(graph)
util.show()

# %%
import json
from ml_dcs.internal.graph.graph import Graph2Util
from ml_dcs.domain.ml_gnn import GNNTrainingResult
from ml_dcs.domain.graph import Graph2, LearningCurveGraphData

with open(GNN_INPUT_PATH_L2, "r") as f:
    data_dict = json.load(f)
data_model = GNNTrainingResult(**data_dict)
data = LearningCurveGraphData.from_ml_gnn_training_result_class_div1000(data_model)
graph = Graph2(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    y1_legend=Y1_LEGEND,
    y2_legend=Y2_LEGEND,
    y_lim=Y_LIM,
    order_of_mag=MAGNITUDE
)
util = Graph2Util(graph)
util.show()

# %%
import json
from ml_dcs.internal.graph.graph import Graph2Util
from ml_dcs.domain.ml_gnn import GNNTrainingResult
from ml_dcs.domain.graph import Graph2, LearningCurveGraphData

with open(GNN_INPUT_PATH_L3, "r") as f:
    data_dict = json.load(f)
data_model = GNNTrainingResult(**data_dict)
data = LearningCurveGraphData.from_ml_gnn_training_result_class_div1000(data_model)
graph = Graph2(
    data=data,
    x_label=X_LABEL,
    y_label=Y_LABEL,
    y1_legend=Y1_LEGEND,
    y2_legend=Y2_LEGEND,
    y_lim=Y_LIM,
    order_of_mag=MAGNITUDE
)
util = Graph2Util(graph)
util.show()
