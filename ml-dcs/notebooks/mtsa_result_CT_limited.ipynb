# %%
from ml_dcs.internal.ml.prediction_methods import RandomForestPrediction
from ml_dcs.internal.mtsa.data_utils import MTSADataUtil
from ml_dcs.domain.ml import MLCalculationTimePredictionInput2

util = MTSADataUtil(input_dir_path="./tmp/2024-08-11/input")
df = util.get_dataframe(ml_input_class=MLCalculationTimePredictionInput2)
prediction = RandomForestPrediction(df)
result = prediction.evaluate(10**5)
print(result.model_dump())
prediction.plt_show()
# Out:
# {'r2_score': -1.9685373085589433, 'mae': 8979.580714285714}

# %%
from ml_dcs.internal.ml.prediction_methods import GradientBoostingPrediction
from ml_dcs.internal.mtsa.data_utils import MTSADataUtil
from ml_dcs.domain.ml import MLCalculationTimePredictionInput2

util = MTSADataUtil(input_dir_path="./tmp/2024-08-11/input")
df = util.get_dataframe(ml_input_class=MLCalculationTimePredictionInput2)
prediction = GradientBoostingPrediction(df)
result = prediction.evaluate(10**5)
print(result.model_dump())
prediction.plt_show()
# Out:
# {'r2_score': -1.263711620622682, 'mae': 7665.222301351809}

# %%
from ml_dcs.internal.ml.prediction_methods import DecisionTreePrediction
from ml_dcs.internal.mtsa.data_utils import MTSADataUtil
from ml_dcs.domain.ml import MLCalculationTimePredictionInput2

util = MTSADataUtil(input_dir_path="./tmp/2024-08-11/input")
df = util.get_dataframe(ml_input_class=MLCalculationTimePredictionInput2)
prediction = DecisionTreePrediction(df)
result = prediction.evaluate(10**5)
print(result.model_dump())
prediction.plt_show()
# Out:
# {'r2_score': -0.49251813491052787, 'mae': 5967.0}

# %%
from ml_dcs.internal.ml.prediction_methods import LogisticRegressionPrediction
from ml_dcs.internal.mtsa.data_utils import MTSADataUtil
from ml_dcs.domain.ml import MLCalculationTimePredictionInput2

util = MTSADataUtil(input_dir_path="./tmp/2024-08-11/input")
df = util.get_dataframe(ml_input_class=MLCalculationTimePredictionInput2)
prediction = LogisticRegressionPrediction(df)
result = prediction.evaluate(10**5)
print(result.model_dump())
prediction.plt_show()
# Out:
# {'r2_score': -1.4516209430416942, 'mae': 8410.857142857143}
